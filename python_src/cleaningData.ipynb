# %% [markdown]
# Antony Tokarr
#
# CFPB Data Analysis - Cleaning Data

# %% [markdown]
# # Imports and Setting up Directories

# %% [markdown]
# Import the necessary packages and modules, import source data.

# %%
#Import necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize'] = 8,4
import warnings
warnings.filterwarnings('ignore')

# %%
# Import csv data
import pandas as pd 
import os
os.chdir('C:/Users/user/Documents/CFPB-Data-Analysis/raw_data/')
df = pd.read_csv('Consumer_Complaints.csv')

# %% [markdown]
# # Exploring the Data and Initial Data Transformation

# %% [markdown]
# First we will explore the data and make initial transformations

# %%
df.head()
# Out:
#   Date received      Product     Sub-product  \
# 0     12/1/2011  Credit card             NaN
# 1     12/1/2011  Credit card             NaN
# 2     12/1/2011  Credit card             NaN
# 3     12/1/2011     Mortgage  Other mortgage
# 4     12/1/2011  Credit card             NaN
#
#                                       Issue Sub-issue  \
# 0     Identity theft / Fraud / Embezzlement       NaN
# 1                      APR or interest rate       NaN
# 2                                     Other       NaN
# 3  Loan modification,collection,foreclosure       NaN
# 4                          Billing disputes       NaN
#
#   Consumer complaint narrative Company public response  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# 2                          NaN                     NaN
# 3                          NaN                     NaN
# 4                          NaN                     NaN
#
# ...

# %% [markdown]
# Structure of dF, view column headers, expected 1,048,575 rows and 18 columns, data imported as expected.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 18 columns):
# Date received                   1048575 non-null object
# Product                         1048575 non-null object
# Sub-product                     853914 non-null object
# Issue                           1048575 non-null object
# Sub-issue                       631048 non-null object
# Consumer complaint narrative    331077 non-null object
# Company public response         380582 non-null object
# Company                         1048575 non-null object
# State                           1032426 non-null object
# ZIP code                        955314 non-null object
# Tags                            142725 non-null object
# Consumer consent provided?      589649 non-null object
# Submitted via                   1048575 non-null object
# Date sent to company            1048575 non-null object
# Company response to consumer    1048574 non-null object
# ...

# %% [markdown]
# Clean column headers up

# %%
df.columns = ['DateReceived', 'Product', 'SubProduct', 'Issue','SubIssue','ConsumerComplaintNarrative', 
               'CompanyPublicResponse', 'Company', 'State', 'ZIPCode', 'Tags', 'ConsumerConsentProvided?',
               'SubmittedVia', 'DateSentToCompany', 'CompanyResponseToConsumer', 'TimelyResponse', 
               'ConsumerDisputed?', 'ComplaintID']

# %% [markdown]
# Columns not relevant to our investigation:
#
# CompanyPublicResponse, Tags, ConsumerConsentProvided?, SubmittedVia, DateSentToCompany, TimelyResponse,
# ConsumerDisputed?, ComplaintID

# %%
drop_columns = ['CompanyPublicResponse',
                'Tags',
                'ConsumerConsentProvided?',
                'SubmittedVia',
                'DateSentToCompany',
                'TimelyResponse',
                'ConsumerDisputed?',
                'ComplaintID']

df = df.drop(drop_columns, 1)

# %%
df.head()
# Out:
#   DateReceived      Product      SubProduct  \
# 0    12/1/2011  Credit card             NaN
# 1    12/1/2011  Credit card             NaN
# 2    12/1/2011  Credit card             NaN
# 3    12/1/2011     Mortgage  Other mortgage
# 4    12/1/2011  Credit card             NaN
#
#                                       Issue SubIssue  \
# 0     Identity theft / Fraud / Embezzlement      NaN
# 1                      APR or interest rate      NaN
# 2                                     Other      NaN
# 3  Loan modification,collection,foreclosure      NaN
# 4                          Billing disputes      NaN
#
#   ConsumerComplaintNarrative                               Company State  \
# 0                        NaN     CAPITAL ONE FINANCIAL CORPORATION    TX
# 1                        NaN     CAPITAL ONE FINANCIAL CORPORATION    CA
# 2                        NaN                   SYNCHRONY FINANCIAL    MN
# 3                        NaN                  SUNTRUST BANKS, INC.    TN
# ...

# %%
df.loc[1]
# Out:
# DateReceived                                          12/1/2011
# Product                                             Credit card
# SubProduct                                                  NaN
# Issue                                      APR or interest rate
# SubIssue                                                    NaN
# ConsumerComplaintNarrative                                  NaN
# Company                       CAPITAL ONE FINANCIAL CORPORATION
# State                                                        CA
# ZIPCode                                                   945XX
# CompanyResponseToConsumer                 Closed without relief
# Name: 1, dtype: object

# %%
# Output cleaned dataset
# df.to_csv('Consumer_Complaints_Modified.csv')
